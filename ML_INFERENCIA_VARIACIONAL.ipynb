# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarcalafrioli/MACHINE_LEARNING/blob/main/ML_INFERENCIA_VARIACIONAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inferência Variacional**

# %% [markdown]
# A inferência variacional é um método de aproximação de uma distribuição complexa com alguma família de distribuições parametrizadas. É um empreendimento Bayesiano, onde, sob a a perspectiva deste, você ainda permite que a máquina aprenda com os dados, com a diferença de que você dâ ao modelo uma dica (a *priori*) e permite que a solução (a *posteriori*) seja mais difusa(fuzzy).
# A Infereência Variacional (IV) Serve para abordar situações de incertezas ou poucos dados.
#
# A Inferência variacional permite inferir com poucos dados. Nos casos em que a coleção de dados é cara (Como DNA e RNA), por exemplo, essa Inferência nos dá a possibilidade de codificar o conhecimento do domínio em vez de amostras extras, ajudando a "reduzir" sistematicamente o conhecimento do domínio à medida que se coleta mais exemplos e depende mais dos dados, conforme a figura abaixo:
#
# ![image.png](data:image/png;base64,...)
#
# Nos casos de aplicações críticas de segurança, como finanças e saúde, a incerteza pode afetar todos os aspectos do modelo, mais obviamente a saída prevista. Em vez dotar os pesos e vieses, parâmetros de modelo menos óbvios, é possível dotar os parâmetros com uma distribuição para torná-las fuzzy. A Inferência variacional permite inferir os intervalos de valores razoáveis.
#
# A Inferência variacional também é útil em modelagem generativa, visto que os modelos generativos fornecem uma especificação completa de como os dados foram gerados. Ao gerar uma imagem de um gato ou cachorro, por exemplo há uma representação latente *z*, que carrega significados semânticos. Dessa forma, *z*  descreve um gato siamês. Através de um conjunto de transformações NÃO-LINEARES e passos de amostragem, *z* é transformado em uma imagem real *x* (Ou seja, os valores píxel de um gato siames). Um exemplo bem conhecido é o Auto-Encoder Variacional (VAE).

# %% [markdown]
# # **Referências**

# %% [markdown]
# https://jonathan-hui.medium.com/machine-learning-variational-inference-273d8e6480bb
#
# https://medium.com/data-science/variational-inference-the-basics-f70ac511bcea
#
# https://medium.com/@msuhail153/understanding-variational-inference-ae119f9bc3ed
